# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import fftpack
import scipy

# %%
n_cells = 1000
dir_name = "../results/piston__1000__100.00__0.01__6.28__1.00__0.50"
data_dir = dir_name + "/data/"


data = pd.read_csv(data_dir + 'piston_r_u_p.txt', delimiter='\t', names=['r', 'u', 'p', 't'])
data['x'] = data.index
length = int(len(data.index) / n_cells)

# %%
data
# Out:
#               r         u         p      t      x
# 0.000  1.000000  0.000000  0.600000    0.0  0.000
# 0.001  1.000000  0.000000  0.600000    0.0  0.001
# 0.002  1.000000  0.000000  0.600000    0.0  0.002
# 0.003  1.000000  0.000000  0.600000    0.0  0.003
# 0.004  1.000000  0.000000  0.600000    0.0  0.004
# ...         ...       ...       ...    ...    ...
# 0.995  0.999977  0.000087  0.600079  100.0  0.995
# 0.996  0.999910  0.000020  0.600011  100.0  0.996
# 0.997  0.999842 -0.000047  0.599944  100.0  0.997
# 0.998  0.999775 -0.000115  0.599877  100.0  0.998
# 0.999  0.999708 -0.000182  0.599809  100.0  0.999
#
# [1001000 rows x 5 columns]

# %%
contact_cell = data[data['x']== 0.5].iloc[:-1]

# %%
p_mean = contact_cell['p'].mean()
p_mean
# Out:
# 0.5999819877000001

# %%
contact_cell['p'] -= p_mean
contact_cell['p']
# Out:
# 0.5    0.000018
# 0.5    0.000018
# 0.5    0.000018
# 0.5    0.000018
# 0.5    0.000018
#          ...
# 0.5   -0.000232
# 0.5    0.005867
# 0.5    0.009519
# 0.5    0.009365
# 0.5    0.005701
# Name: p, Length: 1000, dtype: float64

# %%
len(contact_cell)
# Out:
# 1000

# %%
plt.plot(contact_cell.t, contact_cell.p)
plt.show()

# %%
p = contact_cell['p'].iloc[:].to_numpy()

t = contact_cell['t'].iloc[:].to_numpy()

tr = np.linspace(min(t), max(t), len(t)); 

vr = scipy.signal.resample(p, len(t));

# %%
print(min(t),max(t))
# Out:
# 0.0 99.90017

# %%
t[:10]
# Out:
# array([0.       , 0.1001838, 0.200002 , 0.3001657, 0.4001357, 0.5001903,
#        0.6000507, 0.7000276, 0.80001  , 0.9000783])

# %%
tr[:10]
# Out:
# array([0.        , 0.10000017, 0.20000034, 0.30000051, 0.40000068,
#        0.50000085, 0.60000102, 0.70000119, 0.80000136, 0.90000153])

# %%
plt.plot(tr, vr)

# %%
L = len(tr);

Ts = np.mean(np.diff(tr)); 

Fs = 1/Ts;   

Fn = Fs/2;   

FTvr = fftpack.fft(vr)/L;

Fv = np.linspace(0, 1, L//2 +1) * Fn;

len(FTvr[1:len(Fv)])
# Out:
# 500

# %%
plt.plot(Fv, np.abs(FTvr[0:len(Fv)] * 2) )
plt.ylim(0, 0.05)
# Out:
# (0.0, 0.05)
